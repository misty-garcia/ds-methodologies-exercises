# %% [markdown]
# Use the cross validation techniques discussed in the lesson to figure out what kind of model works best with the cars dataset used in the lesson.

# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("used_cars.csv.gz", index_col='Id')

# %%
df.columns = [c.lower() for c in df.columns]

# %%
df
# Out:
#          price  year  mileage             city state                vin  \
# Id
# 1        16472  2015    18681   Jefferson City    MO  KL4CJBSBXFB267643
# 2        15749  2015    27592         Highland    IN  KL4CJASB5FB245057
# 3        16998  2015    13650            Boone    NC  KL4CJCSB0FB264921
# 4        15777  2015    25195      New Orleans    LA  KL4CJASB4FB217542
# 5        16784  2015    22800        Las Vegas    NV  KL4CJBSB3FB166881
# ...        ...   ...      ...              ...   ...                ...
# 297895  172898  2017     4416    Thousand Oaks    CA  WP0CD2A98HS178295
# 297896  171990  2016     2782   Newtown Square    PA  WP0AC2A98GS184221
# 297897  172991  2017     5702           Austin    TX  WP0CD2A90HS178422
# 297898  181990  2017     3850    Rancho Mirage    CA  WP0AD2A94HS166586
# 297899  187900  2017     2523  West Palm Beach    FL  WP0AD2A90HS166844
#
#            make              model
# Id
# 1         Buick  EncoreConvenience
# 2         Buick          EncoreFWD
# 3         Buick      EncoreLeather
# 4         Buick          EncoreFWD
# 5         Buick  EncoreConvenience
# ...         ...                ...
# 297895  Porsche       911Cabriolet
# 297896  Porsche             9112dr
# 297897  Porsche       911Cabriolet
# 297898  Porsche           911Coupe
# 297899  Porsche           911Coupe
#
# [297899 rows x 8 columns]
